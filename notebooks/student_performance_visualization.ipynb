# %%
import pandas as pd
df=pd.read_csv('../data/student_performance.csv')
df.head()
# Out:
#    student_id  study_hours  attendance  exam_score  gender
# 0           1            2          65          45    Male
# 1           2            4          70          55  Female
# 2           3            6          80          65    Male
# 3           4            8          90          78  Female
# 4           5            1          50          40    Male

# %%
df
# Out:
#     student_id  study_hours  attendance  exam_score  gender
# 0            1            2          65          45    Male
# 1            2            4          70          55  Female
# 2            3            6          80          65    Male
# 3            4            8          90          78  Female
# 4            5            1          50          40    Male
# 5            6            3          60          50  Female
# 6            7            5          75          60    Male
# 7            8            7          85          72  Female
# 8            9            9          95          88    Male
# 9           10            2          55          48  Female
# 10          11            4          68          58    Male
# 11          12            6          82          70  Female
# 12          13            8          88          80    Male
# 13          14            5          77          66  Female
# 14          15            7          92          85    Male
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   student_id   20 non-null     int64
#  1   study_hours  20 non-null     int64
#  2   attendance   20 non-null     int64
#  3   exam_score   20 non-null     int64
#  4   gender       20 non-null     str
# dtypes: int64(4), str(1)
# memory usage: 932.0 bytes
#        student_id  study_hours  attendance  exam_score
# count    20.00000    20.000000   20.000000   20.000000
# mean     10.50000     5.350000   77.000000   65.850000
# std       5.91608     2.433862   13.787867   15.037759
# min       1.00000     1.000000   50.000000   40.000000
# 25%       5.75000     3.750000   67.250000   54.250000
# 50%      10.50000     5.500000   78.500000   65.500000
# 75%      15.25000     7.250000   88.500000   78.500000
# max      20.00000     9.000000   98.000000   90.000000

# %% [markdown]
# ## Project Questions
#
# 1. How do study hours affect exam scores?
# 2. Does attendance impact performance?
# 3. What is the distribution of student scores?

# %%
df.isnull().sum()
# Out:
# student_id     0
# study_hours    0
# attendance     0
# exam_score     0
# gender         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['exam_score'], bins=10, kde=True)
plt.title('Distribution of Exam Scores')
plt.xlabel('Exam Score')
plt.ylabel('Num of Students')
plt.show()

# %%
bins = [40,50,60,70,80,90,100]
plt.hist(df["exam_score"], bins=bins, edgecolor='black', density=False)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(
    x="study_hours",
    y="exam_score",
    data=df,
    hue="gender"
)
plt.title("Study Hours vs Exam Score")
plt.xlabel("Study Hours per Day")
plt.ylabel("Exam Score")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(
    x="attendance",
    y="exam_score",
    data=df,
    hue="gender",      # optional, adds more insight
    s=80               # size of points
)
plt.title("Attendance vs Exam Score")
plt.xlabel("Attendance Percentage")
plt.ylabel("Exam Score")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.regplot(
    x="attendance",
    y="exam_score",
    data=df
)
plt.title("Attendance vs Exam Score with Trendline")
plt.xlabel("Attendance Percentage")
plt.ylabel("Exam Score")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.heatmap(
    df[["study_hours", "attendance", "exam_score"]].corr(),
    annot=True,
    cmap="coolwarm"
)
plt.title("Correlation Between Features")
plt.show()

# %% [markdown]
# ## Key Insights
#
# - Exam scores tend to increase as study hours increase.
# - Students with higher attendance generally perform better.
# - Strong positive correlation exists between study hours and exam scores.
# - Attendance also shows a positive relationship with performance.
